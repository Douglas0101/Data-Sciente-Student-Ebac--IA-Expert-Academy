# %% [markdown]
# # Salvando dataframes em CSV, Excel e JSON

# %%
import pandas as pd
import numpy as np

# %%
np.random.random_sample(size=(100,10))*100
# Out:
# array([[5.11113498e+01, 1.38079956e+01, 9.52128519e+01, 6.37165756e+01,
#         3.63816604e+01, 9.82250837e+01, 6.14492480e+01, 1.25842840e+01,
#         2.43944634e+01, 2.33296722e+00],
#        [7.96759932e+01, 1.56329150e+01, 6.95288501e+01, 4.46037872e+01,
#         6.51739796e+01, 1.65292494e+01, 4.38585119e+01, 8.09610569e+01,
#         2.57855859e+01, 3.07726870e+01],
#        [9.38229209e+01, 3.29676181e+01, 8.11110939e+01, 2.37920476e+01,
#         9.77677322e+01, 3.48990871e+01, 7.97650238e+01, 9.34000135e+01,
#         6.82318926e+01, 8.73605345e+01],
#        [5.74709648e+00, 8.99264136e+00, 5.35231904e+01, 7.85199535e+01,
#         7.47958447e+00, 5.83065013e+01, 6.22357169e+01, 4.43275128e+01,
#         1.45685870e+01, 3.48172145e+01],
#        [4.16394257e+01, 4.25948891e+01, 4.17981537e+01, 6.43841199e+01,
#         8.98601800e+01, 6.96106607e+01, 5.16251219e+01, 6.00926656e+01,
#         2.24749834e+01, 7.54097974e+00],
# ...

# %%
df = pd.DataFrame(np.random.random_sample(size=(100,10))*100, columns = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'])
df
# Out:
#             A          B          C          D          E          F  \
# 0   38.047279  31.085320  89.640886  60.785812  52.343040  71.162635
# 1   33.554723  83.243432  78.702163  57.077452  91.551827  87.323398
# 2   92.702173   5.630601  88.136254   7.473894   7.355872  62.732763
# 3   15.704822  36.372575  76.168676  76.161069  93.758113  97.874690
# 4   37.340655  85.659355   1.395064  92.727904  84.083564  97.516812
# ..        ...        ...        ...        ...        ...        ...
# 95  57.544727  21.206075   2.764779  94.209679  67.634364  11.310941
# 96  14.818391  88.823051   0.964933  67.124158  65.460126  61.104513
# 97  53.298224   5.551462  24.561062  59.574479   1.449761  93.515063
# 98  52.685540  88.896354  65.650374  97.909944  81.213986  63.467892
# 99  76.087875   7.763330  57.588200  46.924186   8.270078  97.483699
#
#             G          H          I          J
# 0   15.009926  63.160347   3.480459  94.040569
# ...

# %%
df.head(1)
# Out:
#            A          B          C         D          E          F          G  \
# 0  23.045008  60.884331  89.614262  76.98885  76.374402  85.205907  73.344131
#
#            H       I          J
# 0  20.694361  90.179  88.058738

# %% [markdown]
# ## Salvando em CSV

# %%
df.to_csv('dataframe_aleatorio.csv')

# %%
df.to_csv('./output/dataframe_aleatorio.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.to_csv('./output/dataframe_aleatorio.csv')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
# ...

# %%
df.to_csv('./output/dataframe_aleatorio_index.csv', index= False)

# %%
df.to_csv('./output/dataframe_aleatorio_index_sep.csv', index= False, sep=';')

# %%
df.to_csv('./output/dataframe_aleatorio_index_sep_dec.csv', index= False, sep=';', decimal=',')

# %% [markdown]
# ## Salvando em Excel

# %%
df.to_excel('./output/dataframe_aleatorio.xlsx')

# %%
df.to_excel('./output/dataframe_aleatorio_index.xlsx', index=False, startrow=1, sheet_name='aleatorio')

# %% [markdown]
# ## Salvando em JSON

# %%
df.to_json('./output/dataframe_aleatorio.json')
